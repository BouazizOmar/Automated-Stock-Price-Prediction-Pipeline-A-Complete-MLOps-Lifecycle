# %%
import os
import requests
from dotenv import load_dotenv
import pandas as pd
import matplotlib.pyplot as plt

# %%
from bs4 import BeautifulSoup

# %%
load_dotenv()
NEWS_API_KEY = os.getenv('NEWS_API')

NEWS_API_URL = 'https://newsapi.org/v2/everything'

# %%
def fetch_news():
    params = {
        'q': 'IBM',
        'from': '2024-11-20',
        'to': '2024-11-27',
        'sortBy': 'relevancy',
        'apiKey': NEWS_API_KEY,
    }
    response = requests.get(NEWS_API_URL, params=params)
    if response.status_code == 200:
        return response.json().get('articles', [])
    else:
        print(f"Error fetching news: {response.status_code}")
        return []

articles = fetch_news()

if articles:
    for article in articles:
        title = article.get('title', 'No Title')
        description = article.get('description', 'No Description')
        content = f"{title}. {description}"
else:
    print("No articles found.")

# %%
articles
# Out:
# [{'source': {'id': None, 'name': 'Ibm.com'},
#   'author': None,
#   'title': 'IBM Quantum delivers on 2022 100x100 performance challenge',
#   'description': 'At IBM Quantum Developer Conference 2024, IBM is enabling algorithm discovery with high-performance quantum computers and easy-to-use quantum software.',
#   'url': 'https://www.ibm.com/quantum/blog/qdc-2024',
#   'urlToImage': 'https://research-website-prod-cms-uploads.s3.us.cloud-object-storage.appdomain.cloud/QDC_Character_Loop_16x9_1920_f0ee4d9893.gif',
#   'publishedAt': '2024-11-22T09:59:23Z',
#   'content': 'Two years ago, IBM® set an ambitious challenge for the quantum computing community: Develop quantum algorithms incorporating circuits with 100 qubits and gate depths of 100, while IBM would build a q… [+11633 chars]'},
#  {'source': {'id': None, 'name': 'Theregister.com'},
#   'author': 'Thomas Claburn',
#   'title': "Kyndryl insiders say there's little new business",
#   'description': 'IT giant aims to end revenue slide by March, former employees have doubts\nSpecial report Kyndryl, the managed infrastructure services business spun out of IBM in 2021, earlier this month repeated its somewhat glum prediction that its revenue will shrink by tw…',
#   'url': 'https://www.theregister.com/2024/11/20/kyndryl_little_new_business/',
#   'urlToImage': 'https://regmedia.co.uk/2024/11/19/shutterstock_kyndryl.jpg',
#   'publishedAt': '2024-11-20T13:22:07Z',
#   'content': 'Special report Kyndryl, the managed infrastructure services business spun out of IBM in 2021, earlier this month repeated its somewhat glum prediction that its revenue will shrink by two to four perc… [+14324 chars]'},
#  {'source': {'id': None, 'name': 'Theregister.com'},
#   'author': 'Simon Sharwood',
#   'title': "AWS bends to Broadcom's will with VMware Cloud Foundation as-a-service",
#   'description': "Microsoft, Oracle, and IBM are all doing it. Andy Jassy's rent-a-server shop may have felt it was leaving money on the table\nAmazon Web Services has introduced a VMware-as-a-service offering that conforms to Broadcom's licensing schemes.…",
#   'url': 'https://www.theregister.com/2024/11/26/amazon_elastic_vmware_service_preview/',
#   'urlToImage': 'https://regmedia.co.uk/2024/11/26/shutterstock_give_and_take_cloud_road_sign.jpg',
#   'publishedAt': '2024-11-26T08:28:08Z',
#   'content': "Amazon Web Services has introduced a VMware-as-a-service offering that conforms to Broadcom's licensing schemes.\r\nThe forthcoming Amazon Elastic VMware Service (Amazon EVS) will offer the chance to r… [+2768 chars]"},
#  {'source': {'id': None, 'name': 'Xataka.com'},
#   'author': 'Juan Carlos López',
#   'title': 'El MIT ha predicho una forma exótica de materia. Su plan es fabricar el ordenador cuántico más potente que existe',
#   'description': 'No hay un único itinerario que nos separa de los ordenadores cuánticos plenamente funcionales, que estarán dotados de la capacidad de corregir sus propios errores. Las organizaciones que están investigando en el ámbito de la computación cuántica trabajan en v…',
#   'url': 'https://www.xataka.com/investigacion/mit-ha-predicho-forma-exotica-materia-su-plan-fabricar-ordenador-cuantico-potente-que-existe',
#   'urlToImage': 'https://i.blogs.es/23fb5d/cubit-ap/840_560.jpeg',
#   'publishedAt': '2024-11-24T12:31:00Z',
#   'content': 'No hay un único itinerario que nos separa de los ordenadores cuánticos plenamente funcionales, que estarán dotados de la capacidad de corregir sus propios errores. Las organizaciones que están invest… [+4741 chars]'},
#  {'source': {'id': None, 'name': 'Genbeta.com'},
#   'author': 'Bárbara Bécares',
#   'title': 'Lo despiden de Amazon y acaba teletrabajando a tiempo completo en tres grandes tech: no quería depender "del capricho de una empresa"',
#   'description': 'Al comienzo de la pandemia, Bryan Roque perdió su trabajo como ingeniero de software en Amazon. Y hace un año compartía su historia sobre cómo es una de esas personas que está trabajando en varias empresas a la vez para ganar más dinero sin que estas lo sepan…',
#   'url': 'https://www.genbeta.com/a-fondo/despiden-amazon-acaba-teletrabajando-a-tiempo-completo-tres-grandes-tech-no-queria-depender-capricho-empresa',
#   'urlToImage': 'https://i.blogs.es/a5063d/no-revisions-rem8nlye2jo-unsplash/840_560.jpeg',
#   'publishedAt': '2024-11-20T13:00:44Z',
#   'content': 'Al comienzo de la pandemia, Bryan Roque perdió su trabajo como ingeniero de software en Amazon. Y hace un año compartía su historia sobre cómo es una de esas personas que está trabajando en varias em… [+3231 chars]'},
#  {'source': {'id': None, 'name': 'heise online'},
#   'author': 'Harald Weiss',
#   'title': 'Weiter Weg zur Open-Source-KI: Red Hat prescht vor',
#   'description': 'Protagonisten von Open Source wollen eine leistungsstarke offene KI-Welt aufbauen. Red Hat wagt sich vor, doch der Weg dürfte noch weit sein.',
#   'url': 'https://www.heise.de/news/Weiter-Weg-zur-Open-Source-KI-Red-Hat-prescht-vor-10178414.html',
#   'urlToImage': 'https://heise.cloudimg.io/bound/1200x1200/q85.png-lossy-85.webp-lossy-85.foil1/_www-heise-de_/imgs/18/4/7/5/2/2/2/8/2024-02-26-Bing-Designer-Robot_Head_Globe_AI-2-3840px-ce923e6d08ec5bbb.png',
#   'publishedAt': '2024-11-27T16:07:00Z',
#   'content': 'Inhaltsverzeichnis\r\nDie KI-Plattform OpenShift AI erhält in Version 2.15 etliche neue Funktionen, darunter eine Model Registry als zentrale Verwaltung der Modelle. Damit kann man prädiktive sowie gen… [+7902 chars]'},
#  {'source': {'id': None, 'name': 'CNET'},
#   'author': 'Barbara Pazur',
#   'title': 'What Is Generative AI? Everything to Know About the Tech Behind ChatGPT and Gemini',
#   'description': "There hasn't been a tech advancement that's caused such a boom since the internet and, later, the iPhone.",
#   'url': 'https://www.cnet.com/tech/services-and-software/what-is-generative-ai-everything-to-know-about-the-tech-behind-chatgpt-and-gemini/',
#   'urlToImage': 'https://www.cnet.com/a/img/resize/c5f49cef62319fa06f5f699ee065ee4228c178dc/hub/2024/11/22/1e35212a-cbcc-4775-94f6-3bd66f665aaf/gettyimages-1442265733.jpg?auto=webp&fit=crop&height=675&width=1200',
#   'publishedAt': '2024-11-26T13:00:07Z',
#   'content': "Artificial intelligence is everywhere, whether you realize it or not. It's behind the chatbots you talk to online, the playlists you stream and the personalized ads that somehow know exactly what you… [+6912 chars]"},
#  {'source': {'id': None, 'name': 'Forbes'},
#   'author': 'Robert B. Tucker, Contributor, \n Robert B. Tucker, Contributor\n https://www.forbes.com/sites/robertbtucker/',
#   'title': 'Mastering The Futurist Mindset: Six Leadership Strategies For Navigating The Singularity',
#   'description': 'Companies such as Intel, IBM, Chevron and many others once dominated their industries.',
#   'url': 'https://www.forbes.com/sites/robertbtucker/2024/11/25/mastering-the-futurist-mindset-six-leadership-strategies-for-navigating-the-singularity/',
#   'urlToImage': 'https://imageio.forbes.com/specials-images/imageserve/6744dce10092efc9f9dad901/0x0.jpg?format=jpg&height=900&width=1600&fit=bounds',
#   'publishedAt': '2024-11-25T22:04:31Z',
#   'content': 'AI will change how we work, futurists will help you change how you think. \r\ngetty\r\nIn a world thats shifting faster than we can often comprehend, the ability to anticipate the direction of change isn… [+8628 chars]'},
#  {'source': {'id': None, 'name': 'Habr.com'},
#   'author': 'beeline_cloud (beeline cloud)',
#   'title': 'Движение вверх: как стать CTO — на примере пяти историй ИТ-директоров',
#   'description': 'Путь от новичка до CTO долог, извилист и полон сайд-квестов. Можно ли пройти всю миссию в одной компании? Поможет ли карьере докторская диссертация? Или, может быть, проще назначить себя директором в стартапе? Мы в beeline cloud изучили истории нескольких спе…',
#   'url': 'https://habr.com/ru/companies/beeline_cloud/articles/861592/#post-content-body',
#   'urlToImage': 'https://habrastorage.org/getpro/habr/upload_files/59e/efa/1c8/59eefa1c8afae464613cf1cb908d0534.jpg',
#   'publishedAt': '2024-11-26T18:52:49Z',
#   'content': 'CTO , -. ? ? , , ? beeline cloud , CTO - , .\r\n : - , .\r\n Reinis Birznieks Unsplash.com\r\n: \r\n : CTO , , -. , - .\r\n, Notch . , , 180 . , Notch . Head of Engineering, .\r\n , , « » , , , , . .\r\n, . Zippia… [+1206 chars]'},
#  {'source': {'id': None, 'name': 'VentureBeat'},
#   'author': 'Michael Nuñez',
#   'title': 'Exclusive: Lightricks bets on open-source AI video to challenge Big Tech',
#   'description': 'Lightricks releases LTXV, a breakthrough open-source AI model that generates professional-quality videos in real-time on consumer hardware, challenging tech giants with faster processing speeds and free access for developers.',
#   'url': 'https://venturebeat.com/ai/exclusive-lightricks-bets-on-open-source-ai-video-to-challenge-big-tech/',
#   'urlToImage': 'https://venturebeat.com/wp-content/uploads/2024/11/Screenshot-2024-11-22-at-1.45.40\u202fAM.png?w=1024?w=1200&strip=all',
#   'publishedAt': '2024-11-22T14:00:00Z',
#   'content': 'Join our daily and weekly newsletters for the latest updates and exclusive content on industry-leading AI coverage. Learn More\r\nLightricks, the Israeli company behind the viral photo-editing app Face… [+7576 chars]'},
#  {'source': {'id': None, 'name': 'ZDNet'},
#   'author': 'ZDNET Japan Staff',
#   'title': '日本IBMと京都市、「IBM BlueHubプログラムin Kyoto」開始--生成AIなどで市の発展と新興企業の成長狙う',
#   'description': '日本IBMと京都市は、同市における地域の課題を生成AI技術などの先端テクノロジーを活用して解決するスタートアップ支援プログラム「IBM BlueHubプログラム in Kyoto」を開始する。',
#   'url': 'https://japan.zdnet.com/article/35226454/',
#   'urlToImage': 'https://japan.zdnet.com/storage/2023/07/04/deaf612bd82a184f34420f54cf3484f7/230704_worker_as_1280_87070391.jpeg',
#   'publishedAt': '2024-11-22T03:06:00Z',
#   'content': 'ZDNET JapanZiff DavisZDNET Japan is operated by Asahi Interactive under license from Ziff Davis.\r\nCopyright (c) 2024 ASAHI INTERACTIVE, Inc. All rights reserved. No\r\n reproduction\r\n or republication … [+26 chars]'},
#  {'source': {'id': None, 'name': 'La Vanguardia'},
#   'author': 'Sergio Agudo',
#   'title': 'En un giro de los acontecimientos, IBM ha dado uno de los saltos más importantes de la informática cuántica',
#   'description': 'Uno de los mayores desafíos de la computación cuántica acaba de superarse en los laboratorios de IBM. El futuro de los ordenadores cuánticos cambia con este avance que permite, por primera vez, que dos chips cuánticos diferentes se comuniquen y trabajen en co…',
#   'url': 'https://www.lavanguardia.com/andro4all/tecnologia/en-un-giro-de-los-acontecimientos-ibm-ha-dado-uno-de-los-saltos-mas-importantes-de-la-informatica-cuantica',
#   'urlToImage': 'https://www.lavanguardia.com/andro4all/hero/2024/11/ordenador-cuantico.webp?width=1200',
#   'publishedAt': '2024-11-26T09:01:22Z',
#   'content': 'La computación cuántica acaba de superar un nuevo hito\r\nUno de los mayores desafíos de la computación cuántica acaba de superarse en los laboratorios de IBM. El futuro de los ordenadores cuánticos ca… [+2748 chars]'},
#  {'source': {'id': None, 'name': 'Inside.com.tw'},
#   'author': 'INSIDE 硬塞的網路趨勢觀察',
#   'title': 'AI 助攻考古！秘魯沙漠再發現數百條神祕「納斯卡線」',
#   'description': '人工智慧結合無人機，助考古學家於秘魯沙漠新發現 303 條納斯卡線，使其總數幾近翻倍。山形大學團隊運用此技術，掃描廣袤區域，成果發表於《美國國家科學院院刊》，新發現圖案包含動植物及人物等，揭示更多納斯卡文明的奧秘。',
#   'url': 'https://www.inside.com.tw/article/36874-nazca-lines',
#   'urlToImage': 'https://bucket-image.inkmaginecms.com/version/social/1/image/2024/11/0364088f-2320-4dd3-bb7e-a773c35f2097.jpg',
#   'publishedAt': '2024-11-25T06:24:53Z',
#   'content': '303 \r\nNazca Lines 450 \r\n AI 243 \r\n 30 \r\n 430 30 AI \r\nIBM Marcus Freitag AI 2%\r\n 200 700 \r\n 1,309 500 \r\nMiaSisley\r\nINSIDE Google News IN \r\n INSIDE AI'},
#  {'source': {'id': None, 'name': 'Wwwhatsnew.com'},
#   'author': 'Juan Diego Polo',
#   'title': 'Microsoft y Atom Computing Presentan un Sistema Cuántico con 24 Qubits Lógicos: El Futuro de la Computación',
#   'description': 'Microsoft, en colaboración con Atom Computing, ha dado un paso histórico en la computación cuántica al introducir un sistema capaz de operar con 24 qubits lógicos, el doble de la cifra anterior de 12. Este avance, anunciado en noviembre de 2024, marca un hito…',
#   'url': 'https://wwwhatsnew.com/2024/11/24/microsoft-y-atom-computing-presentan-un-sistema-cuantico-con-24-qubits-logicos-el-futuro-de-la-computacion/',
#   'urlToImage': 'https://wwwhatsnew.com/wp-content/uploads/2024/11/Centro-de-datos-cuantico-de-ultima-generacion-en-funcionamiento.webp',
#   'publishedAt': '2024-11-23T23:00:55Z',
#   'content': 'Microsoft, en colaboración con Atom Computing, ha dado un paso histórico en la computación cuántica al introducir un sistema capaz de operar con 24 qubits lógicos, el doble de la cifra anterior de 12… [+3661 chars]'},
#  {'source': {'id': None, 'name': 'Hipertextual'},
#   'author': 'José María López',
#   'title': 'Macintosh Portable: la historia del Mac que viajó al espacio',
#   'description': 'Hace un tiempo hablé del Macintosh Portable. Fue el primer ordenador portátil de Apple. Uno de los primeros ordenadores de su clase en una época en la que las baterías duraban más bien poco. Pero el primer Mac portátil hizo posible lo que vino después. Hoy en…',
#   'url': 'http://hipertextual.com/2024/11/mac-en-el-espacio',
#   'urlToImage': 'https://i0.wp.com/imgs.hipertextual.com/wp-content/uploads/2023/05/Macintosh-Portable-NASA-Espacio-Tierra.jpg?fit=1920%2C1280&quality=70&strip=all&ssl=1',
#   'publishedAt': '2024-11-20T08:00:00Z',
#   'content': 'Hace un tiempo hablé del Macintosh Portable. Fue el primer ordenador portátil de Apple. Uno de los primeros ordenadores de su clase en una época en la que las baterías duraban más bien poco. Pero el … [+8185 chars]'},
#  {'source': {'id': None, 'name': 'Techbang.com'},
#   'author': 'KKJ',
#   'title': '馬斯克政治、商業兩得意，迪士尼、華納、獅門影業現已恢復在X投放廣告',
#   'description': '迪士尼、華納、獅門影業現已恢復在X投放廣告\n川普當選後，馬斯克無疑是壓對寶，成為當紅的紅人。除了在11月12日，川普宣佈馬斯克將與企業家拉馬斯瓦米（Vivek Ramaswamy）聯手執掌政府效率部，專門拆解官僚、削減開支，並重組聯邦機構之外，看來很多其它企業可能也開始看風向，要壓馬斯克這個王牌了。\n先前馬斯克接管推特（改名X）並且大幅進行改革之後，有許多企業因為覺得不滿X出現了大量仇恨言論、極端主義內容以及反猶等不當言論，而紛紛離開。雖然馬斯克再有錢，但是X的命脈就是廣告，這些指標性的企業在X上抽離廣告，對馬斯…',
#   'url': 'https://www.techbang.com/posts/119657-musk-is-politically-and-commercially-proud-and-disney-warner',
#   'urlToImage': 'https://cdn1.techbang.com/system/excerpt_images/119657/original/90c19d0dcfc25a4cb399c4f632a3713b.jpg?1731925321',
#   'publishedAt': '2024-11-21T01:30:00Z',
#   'content': '1112Vivek Ramaswamy\r\nXXXX\r\n<ol><li>Apple X X </li><li>DisneyX CEO X X </li><li>IBMIBM X IBM X </li><li>LionsgateX </li><li>Warner Bros. Discovery X </li></ol>TwitterX\r\nMediaRadar202419X33020231.798%\r… [+30 chars]'},
#  {'source': {'id': None, 'name': 'Gizmodo.com'},
#   'author': 'Lucas Ropek',
#   'title': 'Researchers Claim to Pinpoint Exact Date When Elon’s X Started Boosting the Right',
#   'description': 'New research suggests that there was a very specific date when rightwing content began to be amplified.',
#   'url': 'https://gizmodo.com/researchers-claim-to-pinpoint-exact-date-when-elons-x-started-boosting-the-right-2000527141',
#   'urlToImage': 'https://gizmodo.com/app/uploads/2024/11/Donald-Trump-and-Elon-Musk-at-a-UFC-fight-in-New-York.jpg',
#   'publishedAt': '2024-11-20T21:50:03Z',
#   'content': 'For a while now, researchers have been trying to prove that X (the platform formerly known as Twitter) has an algorithmic bias for conservative content. Indeed, ever since Elon Musk bought the platfo… [+5991 chars]'},
#  {'source': {'id': None, 'name': 'Inside.com.tw'},
#   'author': 'Sisley',
#   'title': '超混「幽靈工程師」正啃食科技巨頭！全球每年浪費 900 億美元',
#   'description': '研究分析超過 5 萬名工程師程式碼，發現「幽靈工程師」現象。',
#   'url': 'https://www.inside.com.tw/article/36890-',
#   'urlToImage': 'https://bucket-image.inkmaginecms.com/version/social/1/image/2024/11/4fddf8d9-8a5a-49ab-9dd0-fc783168991d.jpg',
#   'publishedAt': '2024-11-27T04:08:41Z',
#   'content': 'Yegor Denisov-Blanch 5 9.5% \r\nPhoto Credit: @yegordb\r\n14% 9% 6%\r\nPhoto Credit: @yegordb\r\nPhoto Credit: @yegordb\r\n58% \r\nPhoto Credit: @yegordb\r\n42% \r\nIBM 18 1.71 25.7 \r\nMicrosoft 11 1.05 15.7 \r\n Googl… [+203 chars]'},
#  {'source': {'id': None, 'name': 'Inside.com.tw'},
#   'author': 'Sisley',
#   'title': '超混「幽靈工程師」正啃食科技巨頭！全球每年浪費 900 億美元',
#   'description': '研究分析超過 5 萬名工程師程式碼，發現「幽靈工程師」現象。',
#   'url': 'https://www.inside.com.tw/article/36890-phantom-engineers-are-draining-tech-giants-wasting-90-billion-globally-each-year',
#   'urlToImage': 'https://bucket-image.inkmaginecms.com/version/social/1/image/2024/11/4fddf8d9-8a5a-49ab-9dd0-fc783168991d.jpg',
#   'publishedAt': '2024-11-27T04:08:41Z',
#   'content': 'Yegor Denisov-Blanch 5 9.5% \r\nPhoto Credit: @yegordb\r\n14% 9% 6%\r\nPhoto Credit: @yegordb\r\nPhoto Credit: @yegordb\r\n58% \r\nPhoto Credit: @yegordb\r\n42% \r\nIBM 18 1.71 25.7 \r\nMicrosoft 11 1.05 15.7 \r\n Googl… [+203 chars]'},
#  {'source': {'id': None, 'name': 'Olhardigital.com.br'},
#   'author': 'Rodrigo Mozelli',
#   'title': 'IBM: IA generativa pode ser ponto importante para tecnologias sustentáveis; entenda',
#   'description': '"Sustentabilidade de TI na Encruzilhada" traz, entre outros temas, os principais usos de quem aplica IAG em suas iniciativas de sustentabilidade e operações de TI\nO post IBM: IA generativa pode ser ponto importante para tecnologias sustentáveis; entenda apare…',
#   'url': 'https://olhardigital.com.br/2024/11/21/pro/ibm-ia-generativa-pode-ser-ponto-importante-para-tecnologias-sustentaveis-entenda/',
#   'urlToImage': 'https://img.odcdn.com.br/wp-content/uploads/2024/11/ia_sustentabilidade.jpg',
#   'publishedAt': '2024-11-21T10:00:00Z',
#   'content': 'Um estudo realizado pela IBM com líderes de tecnologia mostrou que a sustentabilidade no uso da inteligência artificial generativa (IAG) é um dos principais temas na atualidade entre eles.\r\n<ul><li>A… [+1864 chars]'},
#  {'source': {'id': None, 'name': 'Courrier International'},
#   'author': None,
#   'title': 'Quand deux puces quantiques n’en font qu’une',
#   'description': 'Pour bâtir des ordinateurs quantiques, IBM mise sur une approche modulaire. L’entreprise vient de franchir une étape clé\xa0: elle a réussi à relier deux puces quantiques et à les faire fonctionner comme une seule entité.',
#   'url': 'https://www.courrierinternational.com/article/technologie-quand-deux-puces-quantiques-n-en-font-qu-une_224922',
#   'urlToImage': 'https://focus.courrierinternational.com/2024/11/25/233/0/5600/3733/1200/630/60/0/7d39613_1732541645053-quatumchip.jpg',
#   'publishedAt': '2024-11-25T14:03:32Z',
#   'content': 'Il se passe des choses dans le monde de linformatique quantique. Le 20\xa0novembre, une équipe de lentreprise américaine IBM a décrit dans Nature comment elle était parvenue à combiner deux puces quanti… [+1007 chars]'},
#  {'source': {'id': None, 'name': 'Theregister.com'},
#   'author': 'Robin Birtstone',
#   'title': 'Fortify your data',
#   'description': 'How cyber resilient storage hardware can defeat ransomware Sponsored Feature\xa0 Ransomware is everywhere. The FBI and CISA just issued yet another advisory about it.…',
#   'url': 'https://www.theregister.com/2024/11/26/fortify_your_data/',
#   'urlToImage': 'https://regmedia.co.uk/2022/02/17/shutterstock_ransomware.jpg',
#   'publishedAt': '2024-11-26T14:52:06Z',
#   'content': 'Sponsored Feature Ransomware is everywhere. The FBI and CISA just issued yet another advisory about it.\r\nThe average payouts associated with this type of cyber attack are huge. The 2024 Cost of a Dat… [+10150 chars]'},
#  {'source': {'id': None, 'name': 'Android Police'},
#   'author': 'Nick Todorov',
#   'title': 'What is an NPU and how does it help AI magic happen?',
#   'description': 'Neural processing unit: Is there any substance to the fancy name?',
#   'url': 'https://www.androidpolice.com/what-is-npu/',
#   'urlToImage': 'https://static1.anpoimages.com/wordpress/wp-content/uploads/2024/11/what-is-an-npu.jpg',
#   'publishedAt': '2024-11-27T19:00:15Z',
#   'content': 'The "brain" of any modern smartphone is its SoC (system-on-chip), an incredibly complex micromachine. It packs a CPU and GPU, audio and video processing, wireless communication, and power management … [+5524 chars]'},
#  {'source': {'id': 'new-scientist', 'name': 'New Scientist'},
#   'author': 'Matthew Sparkes',
#   'title': 'IBM entangled two quantum chips to work together for the first time',
#   'description': 'IBM has bet big on a modular approach to building quantum computers, and now it has successfully linked two quantum chips together to operate as a single device, a key step towards that goal',
#   'url': 'https://www.newscientist.com/article/2456542-ibm-entangled-two-quantum-chips-to-work-together-for-the-first-time/',
#   'urlToImage': 'https://images.newscientist.com/wp-content/uploads/2024/11/20134718/SEI_230294555.jpg',
#   'publishedAt': '2024-11-20T16:00:39Z',
#   'content': 'An artist’s impression of IBM’s Eagle quantum processing unit\r\nIBM\r\nIBM has made a significant advance on the road to larger and more powerful quantum computers by linking two such devices together a… [+456 chars]'},
#  {'source': {'id': None, 'name': 'Cult of Mac'},
#   'author': 'Luke Dormehl',
#   'title': 'Today in Apple History: Bill Gates hails Mac as the future of computing',
#   'description': 'On November 26, 1984, Bill Gates predicted that "the next generation of interesting software will be done on the Macintosh."\n(via Cult of Mac - Apple news, rumors, reviews and how-tos)',
#   'url': 'https://www.cultofmac.com/apple-history/bill-gates-praises-macintosh',
#   'urlToImage': 'https://www.cultofmac.com/wp-content/uploads/2015/09/fee80429245125.55e9120e85a0a-2.jpg',
#   'publishedAt': '2024-11-26T16:11:06Z',
#   'content': 'November 26, 1984: The next generation of interesting software will be done on the Macintosh, not the IBM PC, predicts Microsoft co-founder Bill Gates in a BusinessWeek cover story. Gates praise for … [+1853 chars]'},
#  {'source': {'id': None, 'name': 'Biztoc.com'},
#   'author': 'go.theregister.com',
#   'title': "AWS bends to Broadcom's will with VMware Cloud Foundation as-a-service",
#   'description': "Microsoft, Oracle, and IBM are all doing it. Andy Jassy's rent-a-server shop may have felt it was leaving money on the table\nAmazon Web Services has introduced a VMware-as-a-service offering that conforms to Broadcom's licensing schemes.…",
#   'url': 'https://biztoc.com/x/443c029b8ff6e370',
#   'urlToImage': 'https://biztoc.com/cdn/808/og.png',
#   'publishedAt': '2024-11-26T08:33:46Z',
#   'content': "Microsoft, Oracle, and IBM are all doing it. Andy Jassy's rent-a-server shop may have felt it was leaving money on the tableAmazon Web Services has introduced a VMware-as-a-service offering that conf… [+101 chars]"},
#  {'source': {'id': None, 'name': 'Hwupgrade.it'},
#   'author': None,
#   'title': 'IBM presenta i primi processori quantistici modulari: ecco Flamingo e Crossbill',
#   'description': 'Nel 2023 IBM aveva presentato Heron, il primo "mattoncino" con cui costruire processori quantistici modulari, e quest\'anno ha svelato il primo risultato di tale sviluppo: arrivano Flamingo e Crossbill',
#   'url': 'https://edge9.hwupgrade.it/news/innovazione/ibm-presenta-i-primi-processori-quantistici-modulari-ecco-flamingo-e-crossbill_132952.html',
#   'urlToImage': 'https://www.hwupgrade.it/i/n/IBM_QDC_2024_720.jpg',
#   'publishedAt': '2024-11-20T14:41:01Z',
#   'content': "IBM è solita tenere una conferenza con le ultime novità legate al mondo quantistico nella seconda metà di novembre. Il 2024 è però il primo anno in cui l'azienda ha tenuto la Quantum Developer Confer… [+5601 chars]"},
#  {'source': {'id': None, 'name': 'Ifanr.com'},
#   'author': '范津瑞',
#   'title': '早报|华为发布 Mate70 系列预热视频，余承东展示新机/爆料称最薄 iPhone 厚度仅 6 毫米/Perplexity 进军电商',
#   'description': '·理想汽车销量突破一百万辆\n·小鹏汽车发布 2024 年第三季度财报\n·索尼新一代全画幅旗舰微单 A1 Ⅱ 正式发布#欢迎关注爱范儿官方微信公众号：爱范儿（微信号：ifanr），更多精彩内容第一时间为您奉上。\n爱范儿 |\n原文链接 ·\n查看评论 ·\n新浪微博',
#   'url': 'https://www.ifanr.com/1606598',
#   'urlToImage': 'https://s3.ifanr.com/images/ep/cover-images/dao_li_cover.jpg',
#   'publishedAt': '2024-11-20T01:00:55Z',
#   'content': 'Mate70 \r\n11 19 Mate70 \r\n Mate70 Mate70 11 26 \r\n19 BG BU Mate70 \r\niPhone 17 \r\nJeff Pu iPhone 17 \r\niPhone 17 iPhone 17 Plus iPhone 17 Air 6mm iPhone 6 6.9mm \r\niPhone 17 Air 4800 2400 A19 6.6 8GB \r\niPho… [+2010 chars]'},
#  {'source': {'id': None, 'name': 'heise online'},
#   'author': 'Dr. Michael Stal',
#   'title': 'Künstliche Superintelligenz (ASI) und Allgemeine Künstliche Intelligenz (AGI)',
#   'description': 'Sind große Sprachmodelle tatsächlich kurz vor dem Erreichen eines menschlichen Niveaus, wie in einigen Publikationen und YouTube-Kanälen behauptet?',
#   'url': 'https://www.heise.de/blog/Alles-super-oder-was-Was-das-I-in-KI-nicht-bedeutet-10039060.html?wt_mc=rss.red.ho.ho.atom.beitrag.beitrag',
#   'urlToImage': 'https://heise.cloudimg.io/bound/1200x1200/q85.png-lossy-85.webp-lossy-85.foil1/_www-heise-de_/imgs/18/4/7/1/6/4/7/1/C3C568A2-95CE-4F3C-91FE-CC33DCD5156E-a9ce9d4679c9e87b.webp',
#   'publishedAt': '2024-11-20T11:15:00Z',
#   'content': 'Inhaltsverzeichnis\r\nIn derzeitigen Diskussionen über generative Künstliche Intelligenz werden häufig Begriffe wie Künstliche Superintelligenz (ASI Artificial Super Intelligence) und Allgemeine Künstl… [+7986 chars]'},
#  {'source': {'id': None, 'name': 'Osnews.com'},
#   'author': 'Thom Holwerda',
#   'title': 'Linux to lose support for Apple and IBM’s failed PowerPC Common Hardware Reference Platform',
#   'description': 'Ah, the Common Hardware Reference Platform, IBM’s and Apple’s ill-fated attempt at taking on the PC market with a reference PowerPC platform anybody could build and expand upon while remaining (mostly) compatible with one another. Sadly, like so many other th…',
#   'url': 'https://www.osnews.com/story/141178/linux-to-lose-support-for-apple-and-ibms-failed-powerpc-common-hardware-reference-platform/',
#   'urlToImage': None,
#   'publishedAt': '2024-11-20T23:09:33Z',
#   'content': 'Ah, the Common Hardware Reference Platform, IBM’s and Apple’s ill-fated attempt at taking on the PC market with a reference PowerPC platform anybody could build and expand upon while remaining (mostl… [+1603 chars]'},
#  {'source': {'id': None, 'name': 'Iphones.ru'},
#   'author': 'Павел',
#   'title': 'Откуда появились смайлики и эмодзи от самых первых до современных. Не поверите, но им больше 300 лет',
#   'description': 'В 2024 году эмодзи кажутся такой же естественной вещью, как любой другой язык. Странно, что за всю свою историю человек не придумал их с появлением письменности пять с половиной тысяч лет назад, а создал «смайлик» только в 20 веке. Но так оно и есть. Ниже узн…',
#   'url': 'https://www.iphones.ru/iNotes/kak-menyalis-emodzi-za-vsyu-istoriyu-tak-vyglyadel-pervyy-',
#   'urlToImage': 'https://www.iphones.ru/wp-content/plugins/wonderm00ns-simple-facebook-open-graph-tags/fbimg.php?img=https%3A%2F%2Fwww.iphones.ru%2Fwp-content%2Fuploads%2F2024%2F11%2F1981.jpg',
#   'publishedAt': '2024-11-21T13:00:31Z',
#   'content': '2024 , .\r\n, , «» 20 .\r\n .\r\n : 400 , :-), Apple Unicode, iOS , .\r\n , .\r\n:\r\n: , \r\n, , .\r\n , , .\r\n ( ) – , Unicode. , .\r\n – (:-), ¯\\()/¯). «» ( )\r\n – , ( – )\r\n – , ( – )\r\n – , (, :), ). , , .\r\n , , .\r\n,… [+1729 chars]'},
#  {'source': {'id': None, 'name': 'Ilsoftware.it'},
#   'author': 'Michele Nasi',
#   'title': 'L’incredibile storia dei sorgenti di IBM CP/67 CMS trovati in un cassonetto',
#   'description': "Negli anni '60, IBM rivoluzionò l'informatica con CP/67 CMS, un sistema operativo pioniere della virtualizzazione, precursore di z/VM. Un gruppo di esperti ne ha fatto riemergere il codice sorgente da un cassonetto della spazzatura.",
#   'url': 'https://www.ilsoftware.it/lincredibile-storia-dei-sorgenti-di-ibm-cp-67-cms-trovati-in-un-cassonetto/',
#   'urlToImage': 'https://www.ilsoftware.it/app/uploads/2024/11/codice-sorgente-IBM-CP67-virtualizzazione.jpg',
#   'publishedAt': '2024-11-27T09:59:25Z',
#   'content': 'Sebbene oggi il termine sia sulla bocca di tutti, potete immaginare come negli anni ’60 parlare di virtualizzazione fosse qualcosa di assolutamente pionieristico. CP/67 CMS (Control Program/67Convers… [+4129 chars]'},
#  {'source': {'id': None, 'name': 'Zoomit.ir'},
#   'author': 'هوشیار ذوالفقارنسب',
#   'title': 'خطای فراموش\u200cنشدنی اینتل؛ ماجرای باگ معروف پنتیوم',
#   'description': 'در سال ۱۹۹۴، درست زمانی که اینتل برتری پنتیوم\u200c را به\u200cرخ می\u200cکشید، یک خطای ریاضی این شرکت را مجبور به فراخوانی و جمع\u200cآوری پردازنده\u200cهایش کرد.',
#   'url': 'https://www.zoomit.ir/featured-articles/429388-intel-pentium-fdiv-bug/',
#   'urlToImage': 'https://api2.zoomit.ir/media/processeurs-intel-1200x798-1-672f6ae09d7a4047e90e0ee9',
#   'publishedAt': '2024-11-20T10:00:00Z',
#   'content': '« » « » . . C .\r\n Metaware Watcom . Canopus . .\r\n Quake . .\r\n id Software Quake . id Software .\r\n. FDIV . \r\n FDIV . . . CNN . : \r\n . \r\n . . \r\n .\r\n , .\r\n ! . \r\n FDIV IBM . IBM IBM PowerPC . \r\n . . «» … [+127 chars]'},
#  {'source': {'id': None, 'name': 'Lwn.net'},
#   'author': 'daroc',
#   'title': 'Security updates for Wednesday',
#   'description': 'Security updates have been issued by Debian (guix, libmodule-scandeps-perl, needrestart, and thunderbird), SUSE (gh), and Ubuntu (kernel, linux, linux-aws, linux-aws-hwe, linux-azure, linux-azure-4.15, linux-gcp,\n linux-gcp-4.15, linux-hwe, linux-kvm, linux-o…',
#   'url': 'https://lwn.net/Articles/998854/',
#   'urlToImage': None,
#   'publishedAt': '2024-11-20T13:13:11Z',
#   'content': 'Copyright © 2024, Eklektix, Inc.Comments and public postings are copyrighted by their creators.Linux is a registered trademark of Linus Torvalds'},
#  {'source': {'id': None, 'name': 'Quartz India'},
#   'author': 'William Gavin',
#   'title': 'Walmart just became the biggest company to roll back its DEI initiatives',
#   'description': 'Walmart (WMT) is joining a slew of other major corporations — including automakers Toyota Motor (TM) and Ford Motor Co. (F) — in rolling back its diversity, equity, and inclusion (DEI) initiatives after facing potential conservative boycotts. Read more...',
#   'url': 'https://qz.com/walmart-ford-toyota-john-deere-diversity-dei-backlash-1851708143',
#   'urlToImage': 'https://i.kinja-img.com/image/upload/c_fill,h_675,pg_1,q_80,w_1200/bc833ebfcdd046b719ca7b5fbe89bea9.jpg',
#   'publishedAt': '2024-11-26T13:32:00Z',
#   'content': 'In This Story\r\nWalmart (WMT0.00%\r\n) is joining a slew of other major corporations including automakers Toyota Motor (TM0.00%\r\n) and Ford Motor Co. (F0.00%\r\n) in rolling back its diversity, equity, an… [+3133 chars]'},
#  {'source': {'id': None, 'name': 'Diamond.jp'},
#   'author': 'ダイヤモンド編集部',
#   'title': '【無料公開】「半導体10兆円投資を完遂する！」経済安保のドン・甘利明氏、予算獲得に鼻息 - Diamond Premiumセレクション',
#   'description': '政府・自民党は、戦略物資としての半導体の重要性を踏まえ、米IBMと提携して先端半導体の製造を目指すラピダスの創設を強力に後押しした。キーマンである自民党の甘利明・半導体戦略推進議員連盟会長に今後の課題などを聞いた。',
#   'url': 'https://diamond.jp/articles/-/354249',
#   'urlToImage': 'https://dol.ismcdn.jp/mwimgs/a/3/1200/img_a344a16a7566ff83988e40838edc63b3333717.jpg',
#   'publishedAt': '2024-11-21T20:30:00Z',
#   'content': 'IBM5\r\n2023281\r\n5\r\nIT\r\nGAFAGoogleAppleFacebook2021Amazon.com\r\n1\r\n215TSMC1IBM'},
#  {'source': {'id': None, 'name': 'Tomshw.it'},
#   'author': 'Giulia Serena',
#   'title': 'Ora puoi confessarti con Gesù in formato IA (sì, veramente)',
#   'description': "Una chiesa svizzera ha installato un confessionale con un'intelligenza artificiale che simula Gesù, offrendo consigli e guida spirituale ai visitatori. L'iniziativa, parte di un progetto artist...",
#   'url': 'https://www.tomshw.it/hardware/ora-puoi-confessarti-con-gesu-in-formato-ia-si-veramente-2024-11-21',
#   'urlToImage': 'https://www.tomshw.it/storage/media/2024/11/41910/gesu-chatbot-(2).jpg',
#   'publishedAt': '2024-11-21T10:45:29Z',
#   'content': "Una chiesa svizzera ha installato un confessionale con un'intelligenza artificiale che simula Gesù, offrendo consigli e guida spirituale ai visitatori. L'iniziativa, parte di un progetto artistico ch… [+2281 chars]"},
#  {'source': {'id': None, 'name': 'Lightroomkillertips.com'},
#   'author': 'Scott Kelby',
#   'title': 'Why I Don’t Convert My Raw Images To DNG',
#   'description': 'A couple of weeks ago, one of the participants at my Las Vegas workshop asked me about this, and when it did, it kind of made me do a double-take because it’s been so long since I’ve been asked this question. Fewer and fewer of my colleagues are still convert…',
#   'url': 'https://lightroomkillertips.com/why-i-dont-convert-my-raw-images-to-dng-2/',
#   'urlToImage': 'https://lightroomkillertips.com/wp-content/uploads/2024/11/dngfe1.jpg',
#   'publishedAt': '2024-11-22T20:09:10Z',
#   'content': 'A couple of weeks ago, one of the participants at my Las Vegas workshop asked me about this, and when it did, it kind of made me do a double-take because it’s been so long since I’ve been asked this … [+6638 chars]'},
#  {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#   'author': None,
#   'title': 'Are IONQ, FORM, and IBM Stocks Buys Ahead of the Quantum Revolution?',
#   'description': None,
#   'url': 'https://consent.yahoo.com/v2/collectConsent?sessionId=1_cc-session_5aee54cb-7afe-4561-b2bb-8e5e7a0778d7',
#   'urlToImage': None,
#   'publishedAt': '2024-11-27T17:22:50Z',
#   'content': "If you click 'Accept all', we and our partners, including 237 who are part of the IAB Transparency &amp; Consent Framework, will also store and/or access information on a device (in other words, use … [+678 chars]"},
#  {'source': {'id': None, 'name': 'Forbes'},
#   'author': 'Michelle Greenwald, Contributor, \n Michelle Greenwald, Contributor\n https://www.forbes.com/sites/michellegreenwald/',
#   'title': 'How AI Is Revolutionizing New Product Development',
#   'description': 'With all AI related to New Product Development & Marketing, it’s early days full of experimentation & important learnings.',
#   'url': 'https://www.forbes.com/sites/michellegreenwald/2024/11/21/how-ai-is-revolutionizing-new-product-development/',
#   'urlToImage': 'https://imageio.forbes.com/specials-images/imageserve/673e85d3ccb46be44a76c5a0/0x0.jpg?format=jpg&height=900&width=1600&fit=bounds',
#   'publishedAt': '2024-11-21T11:30:00Z',
#   'content': 'Company Employees Generating New Product Ideas Efficiently with AI and GenAI\r\nGenerated By Michelle Greenwald with her own custom GPT\r\nWith all AI related to New Product Development &amp; Marketing, … [+10309 chars]'},
#  {'source': {'id': None, 'name': 'Genbeta.com'},
#   'author': 'Bárbara Bécares',
#   'title': 'Tras 38 años trabajando en la misma empresa, lo despiden con un simple mail un día a las 5 de la mañana',
#   'description': 'En un nuevo capítulo de despidos inhumanos hoy tenemos la historia de un hombre que ha contado en su perfil de LinkedIn que, tras 38 años de servicio a una misma empresa, fue despedido y con un simple mail que le llegó antes de amanecer. La empresa es GM o Ge…',
#   'url': 'https://www.genbeta.com/actualidad/38-anos-trabajando-empresa-despiden-simple-mail-dia-a-5-manana',
#   'urlToImage': 'https://i.blogs.es/ff9f68/pexels-burst-374074/840_560.jpeg',
#   'publishedAt': '2024-11-21T17:07:01Z',
#   'content': 'En un nuevo capítulo de despidos inhumanos hoy tenemos la historia de un hombre que ha contado en su perfil de LinkedIn que, tras 38 años de servicio a una misma empresa, fue despedido y con un simpl… [+1892 chars]'},
#  {'source': {'id': None, 'name': 'Gizmodo.com'},
#   'author': 'Thomas Handley',
#   'title': '¿Una revolución en computación cuántica? El MIT predice una forma exótica de materia',
#   'description': 'El MIT podría estar cerca de cambiar la computación cuántica para siempre. Su predicción sobre partículas exóticas llamadas alones no abelianos plantea la posibilidad de construir ordenadores más confiables y versátiles. ¿Qué hace a estos cúbits tan especiale…',
#   'url': 'https://es.gizmodo.com/una-revolucion-en-computacion-cuantica-el-mit-predice-una-forma-exotica-de-materia-2000136209',
#   'urlToImage': 'https://es.gizmodo.com/app/uploads/2024/11/Tecnologia-cuantica.jpg',
#   'publishedAt': '2024-11-24T15:43:09Z',
#   'content': 'En 1982, los científicos descubrieron que los electrones podían fraccionar su carga eléctrica en circunstancias específicas. Este fenómeno dio lugar a las cuasipartículas fraccionarias, un hallazgo t… [+2635 chars]'},
#  {'source': {'id': 'techradar', 'name': 'TechRadar'},
#   'author': 'Sead Fadilpašić',
#   'title': 'Finance giant Finastra warns clients of potential data breach',
#   'description': 'Finastra is looking into claims of breach made on a darknet forum.',
#   'url': 'https://www.techradar.com/pro/security/finance-giant-finastra-warns-clients-of-potential-data-breach',
#   'urlToImage': 'https://cdn.mos.cms.futurecdn.net/bQXHuL9FnWTzoidAbDo4YE-1200-80.jpg',
#   'publishedAt': '2024-11-21T14:03:00Z',
#   'content': '<ul><li>A threat actor is offering a large database for sale, claims it came from Finastra</li><li>The finance giant sends out data breach notification letter to affected customers, claiming its secu… [+2314 chars]'},
#  {'source': {'id': None, 'name': 'Xataka.com'},
#   'author': 'Juan Carlos López',
#   'title': "EEUU prepara un nuevo 'proyecto Manhattan'. Esta vez la protagonista no es la bomba atómica, lo es la IA",
#   'description': 'EEUU y China se han lanzado a una carrera para ser el primer país capaz de desarrollar una inteligencia artificial general, conocida como AGI por su denominación en inglés (Artificial General Intelligence). Buena parte de las sanciones que han desplegado EEUU…',
#   'url': 'https://www.xataka.com/robotica-e-ia/eeuu-prepara-nuevo-proyecto-manhattan-esta-vez-protagonista-no-bomba-atomica-ia',
#   'urlToImage': 'https://i.blogs.es/71bd2a/agi-ap/840_560.jpeg',
#   'publishedAt': '2024-11-20T10:30:42Z',
#   'content': 'EEUU y China se han lanzado a una carrera para ser el primer país capaz de desarrollar una inteligencia artificial general, conocida como AGI por su denominación en inglés (Artificial General Intelli… [+3969 chars]'},
#  {'source': {'id': 'techradar', 'name': 'TechRadar'},
#   'author': 'erichs211@gmail.com (Eric Hal Schwartz)',
#   'title': 'Meet your own personal AI Jesus in this Swiss church’s confessional',
#   'description': 'Swiss church brings AI-powered Christ to the confessional',
#   'url': 'https://www.techradar.com/computing/artificial-intelligence/meet-your-own-personal-ai-jesus-in-this-swiss-churchs-confessional',
#   'urlToImage': 'https://cdn.mos.cms.futurecdn.net/neYuVpv8rLkNFPo9bWVRbZ-1200-80.png',
#   'publishedAt': '2024-11-20T02:30:00Z',
#   'content': '<ul><li>A church in Switzerland has an AI\xa0Jesus taking confession and offering advice</li><li>The church worked with a local university to design and deploy the AI</li><li>The AI is trained on the Ne… [+2344 chars]'},
#  {'source': {'id': None, 'name': 'Xataka.com'},
#   'author': 'Juan Carlos López',
#   'title': 'La incertidumbre que ha desencadenado la inminente llegada de Trump al Gobierno de EEUU ya hace mella en TSMC',
#   'description': "Las declaraciones que ha hecho Donald Trump acerca de su disconformidad con el programa 'Chips and Science Act', que destina 52.000 millones de dólares específicamente a las empresas de chips, tienen en jaque a los fabricantes de semiconductores con presencia…",
#   'url': 'https://www.xataka.com/empresas-y-economia/incertidumbre-que-ha-desencadenado-inminente-llegada-trump-al-gobierno-eeuu-hace-mella-tsmc',
#   'urlToImage': 'https://i.blogs.es/eb2fe1/tsmc-ap/840_560.jpeg',
#   'publishedAt': '2024-11-20T12:00:44Z',
#   'content': "Las declaraciones que ha hecho Donald Trump acerca de su disconformidad con el programa 'Chips and Science Act', que destina 52.000 millones de dólares específicamente a las empresas de chips, tienen… [+3191 chars]"},
#  {'source': {'id': None, 'name': '[Removed]'},
#   'author': None,
#   'title': '[Removed]',
#   'description': '[Removed]',
#   'url': 'https://removed.com',
#   'urlToImage': None,
#   'publishedAt': '2024-11-21T10:14:45Z',
#   'content': '[Removed]'},
#  {'source': {'id': None, 'name': 'Frandroid'},
#   'author': 'Paul-Emile Cassoret',
#   'title': '« Stellantis applique ce qu’a fait Boeing il y a dix ans » : pourquoi la partie logicielle des voitures Peugeot, Citroën et Fiat risque de poser problème',
#   'description': 'Le groupe Stellantis (Peugeot, Citroën, Fiat, etc.) se lance dans un immense chantier, aussi nécessaire que dangereux : créer un seul et même logiciel pour les 14 marques de voitures du groupe. Et malheureusement, la stratégie du projet semble déjà défaillant…',
#   'url': 'https://www.frandroid.com/survoltes/voitures-electriques/2410344_stellantis-applique-ce-qua-fait-boeing-il-y-a-dix-ans-pourquoi-la-partie-logicielle-des-voitures-peugeot-citroen-et-fiat-risque-de-poser-probleme',
#   'urlToImage': 'https://images.frandroid.com/wp-content/uploads/2024/11/peugeot-e408-2405styp-322-1200x800-1.jpg',
#   'publishedAt': '2024-11-20T13:20:10Z',
#   'content': 'Le groupe Stellantis (Peugeot, Citroën, Fiat, etc.) se lance dans un immense chantier, aussi nécessaire que dangereux : créer un seul et même logiciel pour les 14 marques de voitures du groupe. Et ma… [+4260 chars]'},
#  {'source': {'id': None, 'name': 'The Next Platform'},
#   'author': 'Timothy Prickett Morgan',
#   'title': 'Microsoft Is First to Get HBM-Juiced AMD CPUs',
#   'description': 'Intel was the first of the major CPU makers to add HBM stacked DRAM memory to a CPU package, with the “Sapphire Rapids” Max Series Xeon SP processors. But',
#   'url': 'https://www.nextplatform.com/2024/11/22/microsoft-is-first-to-get-hbm-juiced-amd-cpus/',
#   'urlToImage': 'http://www.nextplatform.com/wp-content/uploads/2024/11/microsoft-azure-hbv5-instance-hardware.jpg',
#   'publishedAt': '2024-11-23T19:40:15Z',
#   'content': 'Intel was the first of the major CPU makers to add HBM stacked DRAM memory to a CPU package, with the Sapphire Rapids Max Series Xeon SP processors. But with the Granite Rapids Xeon 6, Intel abandone… [+13042 chars]'},
#  {'source': {'id': None, 'name': 'Overclockers.ru'},
#   'author': None,
#   'title': 'Как менялись суперкомпьютеры: путь от вакуумных ламп и транзисторов до квантовых вычислений',
#   'description': 'В этой статье мы проследим путь развития суперкомпьютеров: от легендарного CDC 6600 и устройств Сеймура Крэя до наших дней. Десятилетиями эти удивительные машины оставались незаменимыми помощниками учёных, инженеров и военных специалистов.',
#   'url': 'https://overclockers.ru/blog/Fantoci/show/193274/Kak-menyalis-superkomp-jutery-put-ot-vakuumnyh-lamp-i-tranzistorov-do-kvantovyh-vychislenij',
#   'urlToImage': 'https://overclockers.ru/st/legacy/blog/417293/591376_O.jpg',
#   'publishedAt': '2024-11-26T06:07:50Z',
#   'content': ', , , ? , : , .\r\n , . , , . , "" , , . , iPhone , 1990- . \r\n - "" , . , -. XIX " " . , XX . " " (2016), -, .\r\n «» 1929 ( « »). IBM . , « », , . \r\n , .: New York World\r\n , , , , . .\r\n ENIAC (Electroni… [+4013 chars]'},
#  {'source': {'id': None, 'name': 'Haberturk.com'},
#   'author': 'Habertürk',
#   'title': 'Ukrayna: Rusya ilk kez kıtalararası balistik füze kullandı',
#   'description': "Ukrayna'nın Rusya'ya ABD ve İngiltere yapımı füzelerle iki gün peş peşe düzenlediği saldırıların ardından Ukrayna ordusu, Rusya'nın 1000 günü aşan savaş boyunca ilk kez bu sabaha karşı kıtalararası balistik füze (IBM) fırlattığını öne sürdü.",
#   'url': 'https://www.haberturk.com/ukrayna-rusya-ilk-kez-kitalararasi-balistik-fuze-kullandi-3739764',
#   'urlToImage': 'https://im.haberturk.com/l/2024/11/21/ver1732179267/3739764/jpg/1200x628',
#   'publishedAt': '2024-11-21T09:02:33Z',
#   'content': "Rusya-Ukrayna hattnda son günlerde yükselen tansiyon sürüyor. Ukrayna, Beyaz Saray'n izin vermesinden ksa süre sonra ABD yapm Atacms füzelerini frlatmas sonucu Rusya'nn Bryansk bölgesindeki bir asker… [+1343 chars]"},
#  {'source': {'id': None, 'name': 'Exler.ru'},
#   'author': 'Алексей Экслер',
#   'title': 'Рекорд по перемещению больших данных',
#   'description': 'Установлен мировой рекорд по перемещению огромного объема данных на мускульной тяге.\r\n\r\nНет, не шутка. Компании Phison и Verdura в рекламных целях на конференции в Атланте подготовили &quot;штангу&quot;, состоящую массива SSD-накопителей Phison Pascari D205V …',
#   'url': 'https://exler.ru/blog/rekord-po-peremeshcheniyu-bolshikh-dannykh.htm',
#   'urlToImage': 'https://exler.ru/img/blog/image/20241127/67470a7be967d.jpg',
#   'publishedAt': '2024-11-27T12:30:00Z',
#   'content': '.\r\n, . Phison Verdura "", SSD- Phison Pascari D205V 122,88 : 451 , - 282,624 .\r\n , " ", , 282 . , !\r\n , .\r\n , 70 .\r\n . 1956 IBM 305 RAMAC. , 5 .\r\nIBM 305 RAMAC system'},
#  {'source': {'id': None, 'name': 'BBC News'},
#   'author': 'https://www.facebook.com/bbcnews',
#   'title': "De 'laser suicida' a 'número da besta': os estranhos medos que códigos de barras causaram desde sua invenção",
#   'description': 'Criados há 75 anos, os códigos de barras ajudaram a salvar vidas, foram para o espaço e alimentaram o medo do Anticristo.',
#   'url': 'https://www.bbc.com/portuguese/articles/cpvzxvx21v2o',
#   'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_portuguese/9cfb/live/eddf1710-90ac-11ef-abfd-93fdbbdc7adf.jpg',
#   'publishedAt': '2024-11-23T21:39:37Z',
#   'content': 'Crédito, Getty Images\r\nLegenda da foto, Estima-se que cerca de 10 bilhões de códigos de barras sejam escaneados todos os dias ao redor do mundo\r\nArticle information<ul><li>Author, Chris Baraniuk</li>… [+17978 chars]'},
#  {'source': {'id': None, 'name': 'Muylinux.com'},
#   'author': 'J.Pomeyrol',
#   'title': 'La cola de RHEL 9.5 ya está aquí: OpenELA, AlmaLinux, Rocky Linux, Oracle Linux…',
#   'description': 'Si la semana pasada nos hacíamos eco del lanzamiento de\xa0Red Hat Enterprise Linux 9.5, esta hacemos lo propio con todo lo que colea tras cada nueva versión del sistema operativo de Red Hat… Y no es poco, aunque cuesta encontrar una denominación adecuada, habid…',
#   'url': 'https://www.muylinux.com/2024/11/20/rhel-9-5-openela-almalinux-rocky-oracle/',
#   'urlToImage': 'https://www.muylinux.com/wp-content/uploads/2024/11/rhels.jpg',
#   'publishedAt': '2024-11-20T17:32:15Z',
#   'content': 'Si la semana pasada nos hacíamos eco del lanzamiento de\xa0Red Hat Enterprise Linux 9.5, esta hacemos lo propio con todo lo que colea tras cada nueva versión del sistema operativo de Red Hat… Y no es po… [+3894 chars]'},
#  {'source': {'id': None, 'name': 'Prtimes.jp'},
#   'author': '日本アイ・ビー・エム株式会社',
#   'title': 'IBM、IBM Consulting Advantageの機能を拡張し、企業がAIのROIを最大化できるよう支援',
#   'description': '[日本IBM]\n- IBM GraniteがIBM Consulting Advantageのデフォルト・モデルに- IBMの16万人のコンサルタントが、より低コストでより高い顧客価値を提供できるように設計された新しいドメイン能力\n著者：シニア・バ...',
#   'url': 'https://prtimes.jp/main/html/rd/p/000000573.000046783.html',
#   'urlToImage': 'https://prtimes.jp/common/pc_v4/og.png',
#   'publishedAt': '2024-11-21T05:40:01Z',
#   'content': '<ul><li>IBM GraniteIBM Consulting Advantage\r\n</li><li>IBM16\r\n</li></ul> IBM Consulting (Mohamad Ali)\r\nIBMAIIBMIBM Consulting AdvantageIBM Consulting AdvantageIBMAI\r\nIBM (LLM) Granite 3.0IBM Consultin… [+768 chars]'},
#  {'source': {'id': None, 'name': 'Donanimhaber.com'},
#   'author': '',
#   'title': "Türkiye'nin ilk kuantum bilgisayarı yarın tanıtılacak!",
#   'description': 'Google, IBM, Alibaba gibi devlerin ardından Türkiye kendi kuantum bilgisayarını geliştiriyor. TOBB ETÜ tarafından faaliyete sunulacak kuantum bilgisayar yarın tanıtılacak.',
#   'url': 'https://www.donanimhaber.com/turkiye-nin-ilk-kuantum-bilgisayari-yarin-tanitilacak--184384',
#   'urlToImage': 'https://www.donanimhaber.com/images/images/haber/184384/src_340x1912xturkiye-nin-ilk-kuantum-bilgisayari-yarin-tanitilacak.jpg',
#   'publishedAt': '2024-11-20T10:50:00Z',
#   'content': 'a\').click(); event.preventDefault();"&gt;Tam Boyutta GörBilimsel çalmalar için kuantum bilgisayarlardan yararlanyor. Kuantum teknolojileri gibi karmak hesaplamalar için yüksek ilem gücüne sahip kuant… [+4160 chars]'},
#  {'source': {'id': None, 'name': 'Forbes'},
#   'author': 'Jason Andersen, Contributor, \n Jason Andersen, Contributor\n https://www.forbes.com/sites/jasonandersen/',
#   'title': 'Are Agentic Applications A Threat To All Workflow Apps?',
# ...
#   'url': 'https://www.hwupgrade.it/news/cpu/ubitium-vuole-rivoluzionare-l-informatica-con-un-processore-universale-risc-v_133109.html',
#   'urlToImage': 'https://www.hwupgrade.it/i/n/processore-universale_720.jpg',
#   'publishedAt': '2024-11-25T09:11:01Z',
#   'content': "Un processore universale basato su architettura RISC-V: è questo l'obiettivo di Ubitium, startup tedesca che ha recentemente chiuso un round di finanziamento da 3,7 milioni di dollari. I soldi racimo… [+2985 chars]"},
#  {'source': {'id': None, 'name': 'Forbes'},
#   'author': 'Chris Westfall, Contributor, \n Chris Westfall, Contributor\n https://www.forbes.com/sites/chriswestfall/',
#   'title': 'The War on Remote Work',
#   'description': 'The Department of Government Efficiency (DOGE), headed by Elon Musk, is introducing new initiatives targeting remote work. And companies are doing the same.',
#   'url': 'https://www.forbes.com/sites/chriswestfall/2024/11/21/the-war-on-remote-work/',
#   'urlToImage': 'https://imageio.forbes.com/specials-images/imageserve/673f4284afc73b15ca3ae53f/0x0.jpg?format=jpg&crop=2278,1069,x0,y223,safe&height=900&width=1600&fit=bounds',
#   'publishedAt': '2024-11-21T15:00:00Z',
#   'content': "Trying to find a balance isn't getting any easier. \r\ngetty\r\nThe Department of Government Efficiency (DOGE), a nongovernmental governing body headed by Elon Musk and Vivek Ramaswamy, is taking on remo… [+5350 chars]"},
#  {'source': {'id': None, 'name': 'Forbes'},
#   'author': 'John Ottman, Forbes Councils Member, \n John Ottman, Forbes Councils Member\n https://www.forbes.com/councils/forbestechcouncil/people/johnottman1/',
#   'title': 'The Rise Of Enterprise Intelligence',
#   'description': 'GenAI is here to stay, but enterprise data infrastructures have a lot of catching up to do before enterprise AI becomes ubiquitous.',
#   'url': 'https://www.forbes.com/councils/forbestechcouncil/2024/11/21/the-rise-of-enterprise-intelligence/',
#   'urlToImage': 'https://imageio.forbes.com/specials-images/imageserve/65525a4d8e49f3917256b5eb/0x0.jpg?format=jpg&height=900&width=1600&fit=bounds',
#   'publishedAt': '2024-11-21T12:15:00Z',
#   'content': 'John Ottman opines on cloud data management, blockchain, cybersecurity &amp; internet freedom. Chairman, Solix Technologies, Inc. &amp; Minds, Inc.\r\ngetty\r\nEveryone remembers the first time they expe… [+6183 chars]'},
#  {'source': {'id': None, 'name': 'Forbes'},
#   'author': 'Kevin Beasley, Forbes Councils Member, \n Kevin Beasley, Forbes Councils Member\n https://www.forbes.com/councils/forbestechcouncil/people/kevinbeasley/',
#   'title': 'Enterprise Resource Planning Technology Trends As We Move Toward 2025',
#   'description': 'Business strategies are continuously influenced by changes in technology, and 2025 looks to be an incredible year for technical advances.',
#   'url': 'https://www.forbes.com/councils/forbestechcouncil/2024/11/22/enterprise-resource-planning-technology-trends-as-we-move-toward-2025/',
#   'urlToImage': 'https://imageio.forbes.com/specials-images/imageserve/673f73145e218da41da05e03/0x0.jpg?format=jpg&height=900&width=1600&fit=bounds',
#   'publishedAt': '2024-11-22T11:30:00Z',
#   'content': 'Kevin Beasley is the CIO at VAI.\r\ngetty\r\nBusiness strategies are continuously influenced by changes in technology, and 2025 looks to be an incredible year for technical advances. As the business worl… [+6465 chars]'},
#  {'source': {'id': None, 'name': 'Forbes'},
#   'author': 'Rachel Wells, Contributor, \n Rachel Wells, Contributor\n https://www.forbes.com/sites/rachelwells/',
#   'title': "Does It Matter Where You Get Your Bachelor's Degree In 2025?",
#   'description': "If you were to pick the best university or college to study your bachelor's degree, where would it be? In 2025, employers are shifting their approach to hiring graduates.",
#   'url': 'https://www.forbes.com/sites/rachelwells/2024/11/20/does-it-matter-where-you-get-your-bachelors-degree-in-2025/',
#   'urlToImage': 'https://imageio.forbes.com/specials-images/imageserve/661cf2fdc1072fd36282567e/0x0.jpg?format=jpg&height=900&width=1600&fit=bounds',
#   'publishedAt': '2024-11-20T17:00:10Z',
#   'content': 'In 2025, more employers are moving away from the favoritism of Ivy League graduates and are ... [+] re-examining the effectiveness of degree programs in themselves\r\ngetty\r\nIf I were hiring somebody t… [+5245 chars]'},
#  {'source': {'id': None, 'name': 'Forbes'},
#   'author': 'Keith Ferrazzi, Contributor, \n Keith Ferrazzi, Contributor\n https://www.forbes.com/sites/keithferrazzi/',
#   'title': 'How Good Leaders Become Great By Never Leading Alone',
#   'description': 'In an era of volatility and change like AI, clinging to industrial-era leadership models is dangerous. We must shift from top-down leadership to a new model of teamship.',
#   'url': 'https://www.forbes.com/sites/keithferrazzi/2024/11/21/how-good-leaders-become-great-by-never-leading-alone/',
#   'urlToImage': 'https://imageio.forbes.com/specials-images/imageserve/673f7946a39d943a6628b8f7/0x0.jpg?format=jpg&height=900&width=1600&fit=bounds',
#   'publishedAt': '2024-11-21T19:30:11Z',
#   'content': 'We spend too much time looking upward at our leaders. We need to spend more time looking at each ... [+] other and how we work together.\r\ngetty\r\nDavid Brancaccio, host of Marketplace Morning Report, … [+4708 chars]'},
#  {'source': {'id': None, 'name': 'Forbes'},
#   'author': 'Julian Hayes II, Contributor, \n Julian Hayes II, Contributor\n https://www.forbes.com/sites/julianhayesii/',
#   'title': 'Jamie Dimon And Top CEOs On Trump’s Deregulation: A Win For Employees?',
#   'description': 'CEOs like Jamie Dimon, Ed Bastian, and Arvind Krishna see opportunity in Trump’s presidency. Will it bring advantages to the workplace?',
#   'url': 'https://www.forbes.com/sites/julianhayesii/2024/11/24/jamie-dimon-and-top-ceos-on-trumps-deregulation-a-win-for-employees/',
#   'urlToImage': 'https://imageio.forbes.com/specials-images/imageserve/67438b9fc842ce233e14998b/0x0.jpg?format=jpg&height=900&width=1600&fit=bounds',
#   'publishedAt': '2024-11-24T21:15:51Z',
#   'content': 'The upcoming Trump presidency has CEOs optimistic for one big reason.\r\nGetty Images\r\nWith the dust settling on election season, the business community is shifting its focus. As Donald Trump prepares … [+4829 chars]'},
#  {'source': {'id': None, 'name': 'Forbes'},
#   'author': 'Chris Westfall, Contributor, \n Chris Westfall, Contributor\n https://www.forbes.com/sites/chriswestfall/',
#   'title': 'Are Return-To-Office Mandates About Efficiency Or Cutting Costs?',
#   'description': 'The Department of Government Efficiency  headed by Elon Musk, is introducing new initiatives targeting remote work. And companies are doing the same.',
#   'url': 'https://www.forbes.com/sites/chriswestfall/2024/11/21/are-return-to-office-mandates-about-efficiency-or-cutting-costs/',
#   'urlToImage': 'https://imageio.forbes.com/specials-images/imageserve/673f4284afc73b15ca3ae53f/0x0.jpg?format=jpg&crop=2278,1069,x0,y223,safe&height=900&width=1600&fit=bounds',
#   'publishedAt': '2024-11-21T15:00:00Z',
#   'content': "Trying to find a balance isn't getting any easier. \r\ngetty\r\nThe Department of Government Efficiency, a nongovernmental governing body headed by Elon Musk and Vivek Ramaswamy, is taking on remote work… [+4833 chars]"},
#  {'source': {'id': None, 'name': 'Forbes'},
#   'author': 'Vidya Plainfield, Forbes Councils Member, \n Vidya Plainfield, Forbes Councils Member\n https://www.forbes.com/councils/forbesbusinesscouncil/people/vidyaplainfield/',
#   'title': 'Integrated AI Technologies: The Importance Of Partnering People And AI',
#   'description': 'Increasingly, human jobs are being transformed into something more collaborative—a joint effort between human and machine.',
#   'url': 'https://www.forbes.com/councils/forbesbusinesscouncil/2024/11/21/integrated-ai-technologies-the-importance-of-partnering-people-and-ai/',
#   'urlToImage': 'https://imageio.forbes.com/specials-images/imageserve/673e0fa792c00a7b665b1056/0x0.jpg?format=jpg&height=900&width=1600&fit=bounds',
#   'publishedAt': '2024-11-21T15:15:00Z',
#   'content': 'Vidya Plainfield - Growth Officer at TechSpeed Inc.\r\ngetty\r\nArtificial intelligence (AI) has always been a source of both excitement and anxiety. Many of us in business recognize the capacity of AI t… [+5974 chars]'},
#  {'source': {'id': None, 'name': 'Classmethod.jp'},
#   'author': '岩城 匠朗',
#   'title': '[アップデート]Amazon RDS Blue/Green Deploymentsがストレージボリュームの縮小をサポートしました',
#   'description': '[アップデート]Amazon RDS Blue/Green Deploymentsがストレージボリュームの縮小をサポートしました',
#   'url': 'https://dev.classmethod.jp/articles/amazon-rds-blue-green-deployments-storage-volume-shrink/',
#   'urlToImage': 'https://images.ctfassets.net/ct0aopd36mqt/wp-thumbnail-2c57fccc8e2c16d5a63f28901f8904ac/7718b1b99dd3a06f49e762d814b6c3c6/amazon-rds',
#   'publishedAt': '2024-11-26T04:23:27Z',
#   'content': 're:Invent 2024Amazon RDS Blue/Green Deplyments\r\nhttps://aws.amazon.com/jp/about-aws/whats-new/2024/11/amazon-rds-blue-green-deployments-storage-volume-shrink/\r\n RDS\r\nre:PostDB\r\n<ul><li></li><li>AWS D… [+883 chars]'},
#  {'source': {'id': None, 'name': 'Tass.ru'},
#   'author': None,
#   'title': 'Суд отложил рассмотрение иска "Транснефти" к Cisco',
#   'description': 'Компания требует взыскать 193 тыс. руб. убытков',
#   'url': 'https://tass.ru/ekonomika/22456147',
#   'urlToImage': 'https://cdn-storage-media.tass.ru/thumb/ru/ekonomika/22456147?u=2024-11-20T16:30:39.184033',
#   'publishedAt': '2024-11-20T16:30:39Z',
#   'content': ', 20 . //. 19 2025 "" () Cisco 193 . . .\r\n"" . Cisco Systems " ".\r\n "" 83,1 . IBM, Red Hat 12,8 . Citrix 17,1 ., 6 . Cisco.\r\n"" - , . 78,55% , 100% .'},
#  {'source': {'id': None, 'name': 'Naturalnews.com'},
#   'author': 'Cassie B.',
#   'title': 'Texas AG announces investigation of ad cartel that conspired to boycott X',
#   'description': 'Texas Attorney General Ken Paxton has announced that he is investigating a liberal advertising cabal over allegations that it carried out a conspiracy to boycott particular social media platforms. According to a statement by his office, he will be looking int…',
#   'url': 'https://www.naturalnews.com/2024-11-26-texas-ag-investigation-ad-cartel-boycott-x.html',
#   'urlToImage': 'https://www.naturalnews.com/wp-content/uploads/sites/91/2024/11/Censored-Twitter-Tablet-Computer.jpg',
#   'publishedAt': '2024-11-26T06:00:00Z',
#   'content': 'Texas Attorney General Ken Paxton has announced that he is investigating a liberal advertising cabal over allegations that it carried out a conspiracy to boycott particular social media platforms.\r\nA… [+3220 chars]'},
#  {'source': {'id': None, 'name': 'Enter.co'},
#   'author': 'Digna Irene Urrea',
#   'title': 'IBM revela las 3 tendencias de inteligencia artificial para empresa en 2025',
#   'description': 'Este año ha sido testigo del enorme potencial de la inteligencia artificial (IA). Sin embargo, muchas empresas aún se encuentran...',
#   'url': 'https://www.enter.co/empresas/ibm-revela-las-3-tendencias-de-inteligencia-artificial-para-empresa-en-2025/',
#   'urlToImage': 'https://www.enter.co/wp-content/uploads/2024/01/istockphoto-1434742171-612x612-1.jpg',
#   'publishedAt': '2024-11-26T22:30:58Z',
#   'content': 'Este año ha sido testigo del enorme potencial de la inteligencia artificial (IA). Sin embargo, muchas empresas aún se encuentran en la fase de exploración, buscando la mejor manera de integrar esta t… [+2051 chars]'},
#  {'source': {'id': None, 'name': 'TechSpot'},
#   'author': 'Rob Thubron',
#   'title': 'Qualcomm backs off full Intel acquisition, could consider buying select divisions',
#   'description': 'In September, reports claimed that Qualcomm had made a takeover offer to rival Intel. The proposal arrived as Team Blue lurched from one crisis to another, from its poor financial performance leading to mass layoffs and cost-cutting, to the problems with its …',
#   'url': 'https://www.techspot.com/news/105722-qualcomm-backs-off-full-intel-acquisition-could-consider.html',
#   'urlToImage': 'https://www.techspot.com/images2/news/bigimage/2024/11/2024-11-26-image-5.jpg',
#   'publishedAt': '2024-11-26T13:23:00Z',
#   'content': "In brief: It appears that what could have been one of the largest and most disruptive tech acquisitions in history is not going to happen any time soon, if at all. A new report claims that Qualcomm's… [+2993 chars]"},
#  {'source': {'id': None, 'name': 'Zdnet.co.kr'},
#   'author': '김미정 기자',
#   'title': '"삼성전자가 구글 제쳐"…韓, AI 보안 특허 출원 세계 3위',
#   'description': '[지디넷코리아]삼성전자·LG전자 등 한국 기업과 공공기관이 인공지능(AI) 보안 특허 출원 순위에서 일본 기업을 제쳤다.특허청은 2012~2021년 한국을 비롯한 미중, 중국, 일본 유럽에 출원된 AI 보안기술 특허에서 한국이 3위를 기록했다고 25일 밝혔다. 발표에 따르면 해당 5개국 특허청에 출원된 AI 보안 기술 특허는 2012년 27건에 그쳤지만 매년 51%씩 늘어 2021년 1천492건으로 증가했다. 이중 미국이 전체 45.9%로 2천987건을 차지하…',
#   'url': 'https://zdnet.co.kr/view/?no=20241125174255',
#   'urlToImage': 'https://image.zdnet.co.kr/2024/09/21/021cc7df43b66c63b8055db1d54559f5.jpg',
#   'publishedAt': '2024-11-25T08:44:14Z',
#   'content': '·LG \xa0(AI) \xa0.\r\n 2012~2021 , , AI 3 25 .\xa0\r\n 5 AI 2012 27 51% 2021 1492 .\xa0\r\n (AI) . (=)\r\n45.9% 2987 . 30.2%, 7.6%, 3.5% . 2017 .\r\nAI 10 IBM, 9. 6 10 . 7 .\xa0\r\n AI · . LG 5 1 6 .\xa0\r\n AI 68% .\xa0· 26% .\xa0\r\n " A… [+4 chars]'},
#  {'source': {'id': None, 'name': 'Technewsworld.com'},
#   'author': 'TechNewsWorld',
#   'title': 'Nvidia Blackwell Is One Hot Processor',
#   'description': "As AI advances, we'll need more highly dense, incredibly powerful AI processors, which suggests that air cooling in server rooms may become obsolete. Let's talk about Blackwell, water cooling, and why Lenovo's Neptune solution stands out at the moment. The po…",
#   'url': 'https://www.technewsworld.com/story/nvidia-blackwell-is-one-hot-processor-179476.html',
#   'urlToImage': 'https://www.technewsworld.com/wp-content/uploads/sites/3/2024/03/nvidia-blackwell-architecture.jpg',
#   'publishedAt': '2024-11-25T13:00:15Z',
#   'content': 'Nvidia has faced scrutiny this month because some servers with a whopping 72 Blackwell processors were overheating. The issue arose because some initial OEM deployments were not properly water-cooled… [+8102 chars]'},
#  {'source': {'id': None, 'name': 'DIE WELT'},
#   'author': 'Sabine Winkler',
#   'title': "So will sich McDonald's neu erfinden",
#   'description': "Nach wie vor ist McDonald's in Deutschland Marktführer unter den Schnellrestaurants. Doch das Kundenaufkommen sinkt, neue Konzepte müssen her. Nun setzt der Fast-Food-Riese auf einen neuen Masterplan.",
#   'url': 'https://www.welt.de/kmpkt/article254539566/McDonald-s-So-will-der-Fast-Food-Riese-sich-neu-erfinden.html',
#   'urlToImage': 'https://img.welt.de/img/kmpkt/mobile254588586/1647934327-ci16x9-w1200/FILES-US-HEALTH-FAST-FOOD-MCDONALDS.jpg',
#   'publishedAt': '2024-11-27T10:20:24Z',
#   'content': "Nach wie vor ist McDonald's in Deutschland Marktführer unter den Schnellrestaurants. Doch das Kundenaufkommen sinkt, neue Konzepte müssen her. Nun setzt der Fast-Food-Riese auf einen neuen Masterplan… [+7140 chars]"},
#  {'source': {'id': None, 'name': 'Prtimes.jp'},
#   'author': None,
#   'title': '～万博が未来をみちびく～企画展「万博で夢見たサイエンス展」を開催します！前期：12月６日(金)～１月26日(日)／後期：２月５日(水)～４月６日(日)',
#   'description': '[大阪市博物館機構]\n【会期中の関連イベント】\n\n■全国巡回展示「イトカワの石、リュウグウの石」 １月28日(火)～２月11日(火・祝)\n■スペシャルナイト「はやぶさ・はやぶさ２が持ち帰ったもの」 ２月１日(土)\n■スペシャルナイト「月の...',
#   'url': 'https://prtimes.jp/main/html/rd/p/000000065.000135074.html',
#   'urlToImage': 'https://prcdn.freetls.fastly.net/release_image/135074/65/135074-65-0e7c375d6e9931c94e13f156f9262db7-1854x2700.jpg?format=jpeg&auto=webp&fit=bounds&width=2400&height=1260',
#   'publishedAt': '2024-11-27T06:00:19Z',
#   'content': '28()11()\r\n ()\r\n ()\r\nHAYABUSA2 REBORN 12()()\r\n()()\r\n1970\r\nIBM System/360NASA()()\r\n2025\r\n1970\r\n1970EXPO7050005000\r\n1970\r\nIBM System/3601970FACOM mate1980PC\r\n19701970\r\n12()2025()\r\n12()26()()()\r\n28()()\r\n… [+467 chars]'}]

# %%
len(articles)
# Out:
# 100

# %%
data = []
for article in articles:
    data.append({
        "Date": article["publishedAt"].split("T")[0],
        "Title": article["title"],
        "Description": article["description"],
        "Url": article["url"],
    })

# %%
articles_df = pd.DataFrame(data)

# %%
import requests
from bs4 import BeautifulSoup
import time

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36"
}

descriptions = []

for u in articles_df['Url']:
    try:
        r = requests.get(u, headers=headers, timeout=10)
        r.raise_for_status()
        soup = BeautifulSoup(r.text, 'html.parser')
        full_description = " ".join(p.get_text(strip=True) for p in soup.find_all('p'))
        descriptions.append(full_description)
    except requests.exceptions.HTTPError as e:
        print(f"HTTP error for {u}: {e}")
        descriptions.append("")
    except requests.exceptions.RequestException as e:
        print(f"Failed to scrape {u}: {e}")
        descriptions.append("")
    time.sleep(2)  # Avoid overloading the server

articles_df['Full_Description'] = descriptions
# Out:
# HTTP error for https://consent.yahoo.com/v2/collectConsent?sessionId=1_cc-session_5aee54cb-7afe-4561-b2bb-8e5e7a0778d7: 401 Client Error: Unauthorized for url: https://consent.yahoo.com/v2/collectConsent?sessionId=1_cc-session_5aee54cb-7afe-4561-b2bb-8e5e7a0778d7

# %%
len(descriptions)
# Out:
# 100

# %%
articles_df.head()
# Out:
#          Date                                              Title  \
# 0  2024-11-20  Researchers Claim to Pinpoint Exact Date When ...
# 1  2024-11-20  La incertidumbre que ha desencadenado la inmin...
# 2  2024-11-20  Microsoft Flight Simulator 2024 is an unplayab...
# 3  2024-11-20  Lo despiden de Amazon y acaba teletrabajando a...
# 4  2024-11-20  EEUU prepara un nuevo 'proyecto Manhattan'. Es...
#
#                                          Description  \
# 0  New research suggests that there was a very sp...
# 1  Las declaraciones que ha hecho Donald Trump ac...
# 2  Launch day bugs and relentless crashes join th...
# 3  Al comienzo de la pandemia, Bryan Roque perdió...
# 4  EEUU y China se han lanzado a una carrera para...
#
#                                                  Url  \
# 0  https://gizmodo.com/researchers-claim-to-pinpo...
# 1  https://www.xataka.com/empresas-y-economia/inc...
# 2  https://www.windowscentral.com/gaming/microsof...
# 3  https://www.genbeta.com/a-fondo/despiden-amazo...
# 4  https://www.xataka.com/robotica-e-ia/eeuu-prep...
#
#                                     Full_Description
# 0  For a while now, researchers have been trying ...
# 1  Juan Carlos López Las declaraciones que ha hec...
# 2  When you purchase through links on our site, w...
# 3  Bárbara Bécares Al comienzo de la pandemia,Bry...
# 4  Juan Carlos López EEUU y China se han lanzado ...

# %%
articles_df = articles_df.sort_values("Date", ascending=True)
articles_df = articles_df.reset_index(drop=True)

# %%
articles_df.tail()
# Out:
#           Date                                              Title  \
# 95  2024-11-27                    超混「幽靈工程師」正啃食科技巨頭！全球每年浪費 900 億美元
# 96  2024-11-27  Weiter Weg zur Open-Source-KI: Red Hat prescht...
# 97  2024-11-27  L’incredibile storia dei sorgenti di IBM CP/67...
# 98  2024-11-27    EYストラテジー・アンド・コンサルティングと日本IBM、日本企業のDXの加速を目指し協業を強化
# 99  2024-11-27  ～万博が未来をみちびく～企画展「万博で夢見たサイエンス展」を開催します！前期：12月６日(金...
#
#                                           Description  \
# 95                     研究分析超過 5 萬名工程師程式碼，發現「幽靈工程師」現象。
# 96  Protagonisten von Open Source wollen eine leis...
# 97  Negli anni '60, IBM rivoluzionò l'informatica ...
# 98  [日本IBM]\n- AIエージェント製品の「IBM watsonx Orchestrate...
# 99  [大阪市博物館機構]\n【会期中の関連イベント】\n\n■全国巡回展示「イトカワの石、リュウ...
#
#                                                   Url  \
# 95           https://www.inside.com.tw/article/36890-
# 96  https://www.heise.de/news/Weiter-Weg-zur-Open-...
# 97  https://www.ilsoftware.it/lincredibile-storia-...
# 98  https://prtimes.jp/main/html/rd/p/000000579.00...
# 99  https://prtimes.jp/main/html/rd/p/000000065.00...
#
#                                      Full_Description
# 95  史丹佛大學一項最新研究指出，全球軟體產業存在著大量的「幽靈工程師」，這些工程師幾乎沒有任何實...
# 96    Protagonisten von Open Source wollen eine le...
# 97  Hardware Applicativi Sicurezza Reti Cloud OS S...
# 98  PR TIMESのご利用について 資料をダウンロード 日本IBM AIエージェント製品の「I...
# 99  PR TIMESのご利用について 資料をダウンロード 大阪市博物館機構 【会期中の関連イベン...

# %%
text = articles_df['Full_Description'][0]

# %%
import tiktoken
from langchain.text_splitter import RecursiveCharacterTextSplitter

# %%
tokenizer = tiktoken.get_encoding('cl100k_base')

def tiktoken_len(text):
    """Measures the number of tokens in a text."""
    tokens = tokenizer.encode(text, disallowed_special=())
    return len(tokens)

# %%
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,        
    chunk_overlap=0,       
    length_function=tiktoken_len,  
    separators=["\n\n", "\n", " ", ""]
)

# %%
def split_into_chunks(text, chunk_size=1000):
    """Splits text into chunks using RecursiveCharacterTextSplitter."""
    splitter = RecursiveCharacterTextSplitter(
        chunk_size=chunk_size,
        chunk_overlap=0,
        length_function=tiktoken_len,
        separators=["\n\n", "\n", " ", ""]
    )
    return splitter.split_text(text)

# %%
USER_PROMPT_TEMPLATE = """
I'm analyzing the IBM stock market by identifying trends from articles and news. For each article, I'll provide the title and document, and I need you to analyze the sentiment and provide a score between 0 (negative) and 1 (positive). 

Your output must always be a valid JSON string, strictly adhering to the format below:

{{
  "sentiment_score": float
}}

Here’s the format I will provide you:

{{
  "Title": "{title}",
  "Document": "{document}"
}}
"""

# %%
# Chain of Thought Prompt
system_prompt = """
To analyze trends in stock market articles, the following steps will be taken:

Article Input: The user will provide the title and content (document) of the article.

Sentiment Analysis: The model will analyze the sentiment of the article based on the tone of the text, identifying whether it conveys a positive, neutral, or negative sentiment towards the market or a specific stock.

Impact Prediction: The model will assess the potential future impact of the article on stock prices. This includes identifying market trends, factors influencing stock performance (such as company performance, market conditions, or industry news), and making a prediction about whether the stock price will increase, decrease, or remain stable.

Response Format: The model will output the sentiment and predicted impact in the specified JSON format.

Iterative Process: For every new article, the same process will be applied to extract the sentiment and predict the impact on stock prices.

Expected JSON format:
{{
  "sentiment_score": float
}}
"""

# %%
from openai import OpenAI

# %%
OPENAI_KEY = os.getenv("OPENAI_KEY")
client = OpenAI(
    api_key=OPENAI_KEY, 
)

# %%
def analyze_with_gpt(title, document):

    chunks = split_into_chunks(document, chunk_size=1000)
    sentiment_scores = []
    
    for i, chunk in enumerate(chunks):
        user_prompt = USER_PROMPT_TEMPLATE.format(title=title, document=chunk)
        try:
            response = client.chat.completions.create(
                model="gpt-4o-mini",  
                messages=[
                    {"role": "system", "content": system_prompt},
                    {"role": "user", "content": user_prompt}
                ],
                response_format={"type": "json_object"}
            )
            result = response.choices[0].message.content
            result_dict = json.loads(result)
            sentiment_score = float(result_dict.get("sentiment_score", 0))
            sentiment_scores.append(sentiment_score)
        except json.JSONDecodeError as json_error:
            print(f"JSON decode error on chunk {i + 1}: {json_error}")
            sentiment_scores.append(0)  
        except Exception as e:
            print(f"Error with OpenAI API on chunk {i + 1}: {e}")
            sentiment_scores.append(0)  
    
    return sum(sentiment_scores) / len(sentiment_scores) if sentiment_scores else 0

# %%
from tqdm import tqdm

def process_dataframe(df):

    sentiment_scores = []

    for _, row in tqdm(df.iterrows(), total=len(df), desc="Processing articles"):
        title = row["Title"]
        full_description = row["Full_Description"]
        avg_score = analyze_with_gpt(title, full_description)
        sentiment_scores.append(avg_score)
    
    df["Sentiment_Score"] = sentiment_scores
    return df

articles_df_cp = process_dataframe(articles_df)
# Out:
# Processing articles: 100%|██████████| 100/100 [07:27<00:00,  4.47s/it]

# %%
articles_df_cp
# Out:
#           Date                                              Title  \
# 0   2024-11-20  Researchers Claim to Pinpoint Exact Date When ...
# 1   2024-11-20  La incertidumbre que ha desencadenado la inmin...
# 2   2024-11-20  Microsoft Flight Simulator 2024 is an unplayab...
# 3   2024-11-20  Lo despiden de Amazon y acaba teletrabajando a...
# 4   2024-11-20  EEUU prepara un nuevo 'proyecto Manhattan'. Es...
# ..         ...                                                ...
# 95  2024-11-27                    超混「幽靈工程師」正啃食科技巨頭！全球每年浪費 900 億美元
# 96  2024-11-27  Weiter Weg zur Open-Source-KI: Red Hat prescht...
# 97  2024-11-27  L’incredibile storia dei sorgenti di IBM CP/67...
# 98  2024-11-27    EYストラテジー・アンド・コンサルティングと日本IBM、日本企業のDXの加速を目指し協業を強化
# 99  2024-11-27  ～万博が未来をみちびく～企画展「万博で夢見たサイエンス展」を開催します！前期：12月６日(金...
#
#                                           Description  \
# 0   New research suggests that there was a very sp...
# 1   Las declaraciones que ha hecho Donald Trump ac...
# 2   Launch day bugs and relentless crashes join th...
# 3   Al comienzo de la pandemia, Bryan Roque perdió...
# 4   EEUU y China se han lanzado a una carrera para...
# ..                                                ...
# 95                     研究分析超過 5 萬名工程師程式碼，發現「幽靈工程師」現象。
# 96  Protagonisten von Open Source wollen eine leis...
# 97  Negli anni '60, IBM rivoluzionò l'informatica ...
# 98  [日本IBM]\n- AIエージェント製品の「IBM watsonx Orchestrate...
# 99  [大阪市博物館機構]\n【会期中の関連イベント】\n\n■全国巡回展示「イトカワの石、リュウ...
#
#                                                   Url  \
# 0   https://gizmodo.com/researchers-claim-to-pinpo...
# 1   https://www.xataka.com/empresas-y-economia/inc...
# 2   https://www.windowscentral.com/gaming/microsof...
# 3   https://www.genbeta.com/a-fondo/despiden-amazo...
# 4   https://www.xataka.com/robotica-e-ia/eeuu-prep...
# ..                                                ...
# 95           https://www.inside.com.tw/article/36890-
# 96  https://www.heise.de/news/Weiter-Weg-zur-Open-...
# 97  https://www.ilsoftware.it/lincredibile-storia-...
# 98  https://prtimes.jp/main/html/rd/p/000000579.00...
# 99  https://prtimes.jp/main/html/rd/p/000000065.00...
#
#                                      Full_Description  Sentiment_Score
# 0   For a while now, researchers have been trying ...         0.400000
# 1   Juan Carlos López Las declaraciones que ha hec...         0.300000
# 2   When you purchase through links on our site, w...         0.050000
# 3   Bárbara Bécares Al comienzo de la pandemia,Bry...         0.500000
# 4   Juan Carlos López EEUU y China se han lanzado ...         0.400000
# ..                                                ...              ...
# 95  史丹佛大學一項最新研究指出，全球軟體產業存在著大量的「幽靈工程師」，這些工程師幾乎沒有任何實...         0.200000
# 96    Protagonisten von Open Source wollen eine le...         0.475000
# 97  Hardware Applicativi Sicurezza Reti Cloud OS S...         0.550000
# 98  PR TIMESのご利用について 資料をダウンロード 日本IBM AIエージェント製品の「I...         0.833333
# 99  PR TIMESのご利用について 資料をダウンロード 大阪市博物館機構 【会期中の関連イベン...         0.425000
#
# [100 rows x 6 columns]

# %%
articles_df['Sentiment_Category'] = articles_df['Sentiment_Score'].apply(
    lambda x: 'positive' if x >= 0.5 else 'negative'
)

sentiment_counts = (
    articles_df.groupby(['Date', 'Sentiment_Category'])
    .size()  # Count occurrences
    .unstack(fill_value=0)  # Pivot categories into columns
    .reset_index()  # Reset index to make it a DataFrame
)

sentiment_counts.columns = ['Date', 'Negative_Articles', 'Positive_Articles']

sentiment_summary_df = pd.DataFrame(sentiment_counts)

# %%
sentiment_summary_df
# Out:
#          Date  Negative_Articles  Positive_Articles
# 0  2024-11-20                 13                 11
# 1  2024-11-21                  8                 12
# 2  2024-11-22                  4                  6
# 3  2024-11-23                  0                  4
# 4  2024-11-24                  0                  4
# 5  2024-11-25                  3                  5
# 6  2024-11-26                  5                  9
# 7  2024-11-27                  9                  7
