# %%
import os

# %%
# %pwd
# Out:
# 'c:\\Users\\Portable\\OneDrive\\Desktop\\Automated-Stock-Price-Prediction-Pipeline-A-Complete-MLOps-Lifecycle\\research'

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# 'c:\\Users\\Portable\\OneDrive\\Desktop\\Automated-Stock-Price-Prediction-Pipeline-A-Complete-MLOps-Lifecycle'

# %%
import pandas as pd

# %%
df = pd.read_csv(r"data\processed\processed_stock_data.csv")

# %%
df.head(25)
# Out:
#                    date      open      high       low     close   volume  \
# 0   2024-10-18 19:59:00  232.3100  232.3100  232.3100  232.3100        1
# 1   2024-10-18 19:56:00  232.3100  232.3100  232.3100  232.3100        5
# 2   2024-10-18 19:54:00  232.3700  232.4000  232.3700  232.4000      202
# 3   2024-10-18 19:50:00  232.3000  232.3000  232.3000  232.3000        5
# 4   2024-10-18 19:46:00  232.3400  232.3400  232.3000  232.3000        5
# 5   2024-10-18 19:45:00  232.4000  232.4000  232.4000  232.4000       20
# 6   2024-10-18 19:43:00  232.4000  232.4000  232.4000  232.4000       25
# 7   2024-10-18 19:33:00  232.3987  232.3987  232.3987  232.3987        1
# 8   2024-10-18 19:32:00  232.2800  232.2800  232.2800  232.2800       25
# 9   2024-10-18 19:14:00  232.4000  232.4000  232.2100  232.2100       75
# 10  2024-10-18 19:12:00  232.4000  232.4000  232.4000  232.4000       50
# 11  2024-10-18 19:07:00  232.3600  232.3600  232.3600  232.3600        2
# ...

# %%
df.isnull().sum()
# Out:
# date                 0
# open                 0
# high                 0
# low                  0
# close                0
# volume               0
# close_normalized     0
# SMA_20              19
# EMA_20               0
# close_lag1           1
# close_lag3           3
# dtype: int64

# %%
df[["close", "EMA_20", "high", "open", "date", "low", "volume"]].isnull().sum()
# Out:
# close     0
# EMA_20    0
# high      0
# open      0
# date      0
# low       0
# volume    0
# dtype: int64
